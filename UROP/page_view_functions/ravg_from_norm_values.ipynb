# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.dates as dates
from matplotlib.ticker import AutoMinorLocator
import datetime as dt
import numpy as np
import gc

# %%
from pathlib import Path
import pandas as pd
root = Path('dataframe', 'daily_avg_over_yrs')
df = pd.read_csv(root / 'action.csv')
del df['Unnamed: 0']
df.head()
# Out:
#   mth_day     Action  Action_norm
# 0   01-01        NaN          NaN
# 1   01-02  18.100457    -1.290930
# 2   01-03  19.838887    -0.492246
# 3   01-04  18.462805    -1.124457
# 4   01-05  17.146156    -1.729362

# %%
#df['action_ravg'] = df['action_norm'].rolling(window=6,center=True).mean()

# %%
df.loc[df['action_ravg'].idxmax()]['mth_day']
df.loc[df['action_ravg'].idxmax()]['action_ravg']

# %%
df.plot(x='mth_day',y='action_ravg',figsize = (15,8))

# %%
tag_array.index("crime")
# Out:
# 54

# %%
df2 = pd.DataFrame(columns=['tag','date','ravg_value'])
df1 = pd.read_csv("tags.csv")
n = 170
tag_array = df1['tag'].value_counts()[:n].index.tolist()
print(tag_array)
df = pd.read_csv("pg_view_1.csv") 
from pathlib import Path
import pandas as pd
root = Path('dataframe', 'daily_avg_over_yrs')
i = 0
for tag in tag_array:
    tagn = tag+'.csv'
    df = pd.read_csv(root / tagn)
    df.columns = map(str.lower, df.columns)
    date = df.loc[df[tag.lower()+'_ravg'].idxmax()]['mth_day']
    ravg_value = df.loc[df[tag.lower()+'_ravg'].idxmax()][tag.lower()+'_ravg']
    df2.loc[i] = [tag.lower(),date,ravg_value]
    i +=1
# Out:
# ['sci-fi', 'atmospheric', 'action', 'comedy', 'surreal', 'based on a book', 'funny', 'twist ending', 'visually appealing', 'dystopia', 'BD-R', 'dark comedy', 'thought-provoking', 'romance', 'woman director', 'stylized', 'quirky', 'psychology', 'fantasy', 'classic', 'violence', 'murder', 'time travel', 'social commentary', 'revenge', 'thriller', 'space', 'cinematography', 'superhero', 'adventure', 'dark', 'aliens', 'suspense', 'disturbing', 'animation', 'coming of age', 'great soundtrack', 'horror', 'drama', 'Criterion', 'drugs', 'music', 'musical', 'psychological', 'cult film', 'friendship', 'true story', 'based on a true story', 'post-apocalyptic', 'predictable', 'black comedy', 'satire', 'independent film', 'serial killer', 'Nudity (Topless)', 'bittersweet', 'crime', 'family', 'mindfuck', 'dreamlike', 'mystery', 'high school', 'war', 'imdb top 250', 'love', 'artificial intelligence', 'boring', 'World War II', 'mental illness', 'politics', 'tense', 'sequel', 'magic', 'great acting', 'inspirational', 'future', 'violent', 'alternate reality', 'witty', 'nudity (topless)', 'comic book', 'biography', 'religion', 'martial arts', 'anime', 'nonlinear', 'Disney', 'CLV', 'police', 'philosophy', 'emotional', 'parody', 'black and white', 'philosophical', 'Quentin Tarantino', 'survival', 'rape', 'beautiful', 'zombies', 'science fiction', 'gay', 'soundtrack', 'remake', 'history', 'slow', 'plot twist', 'sex', 'based on novel or book', 'multiple storylines', 'humorous', 'documentary', 'robots', 'Betamax', 'gore', 'prison', 'Marvel', 'espionage', 'historical', 'short', 'Oscar (Best Picture)', 'franchise', 'organized crime', 'visually stunning', 'original', 'intelligent', 'corruption', 'touching', 'cyberpunk', 'hilarious', 'dark humor', 'adapted from:book', 'racism', 'futuristic', 'supernatural', 'Leonardo DiCaprio', 'fairy tale', 'heist', 'loneliness', 'suicide', 'DVD-Video', 'military', 'stupid', 'weird', 'Johnny Depp', 'dialogue', 'conspiracy', 'overrated', 'Brad Pitt', 'kidnapping', 'road trip', 'sexuality', 'lesbian', 'assassin', 'New York City', 'small town', 'Oscar Nominee: Best Picture', 'intense', 'ensemble cast', 'clever', 'Tom Hanks', 'Japan', 'strong female lead', 'film noir', 'Pixar', 'creepy', 'stand-up comedy', 'spy', 'Bruce Willis', 'Action', 'death']

# %%
# df2 = df2.sort_values('ravg_value')
df2.tail(50)
# Out:
#                              tag  \
# 120                    franchise
# 121              organized crime
# 122            visually stunning
# 123                     original
# 124                  intelligent
# 125                   corruption
# 126                     touching
# 127                    cyberpunk
# 128                    hilarious
# 129                   dark humor
# 130            adapted from:book
# 131                       racism
# 132                   futuristic
# 133                 supernatural
# 134            leonardo dicaprio
# 135                   fairy tale
# 136                        heist
# 137                   loneliness
# 138                      suicide
# 139                    dvd-video
# 140                     military
# 141                       stupid
# 142                        weird
# 143                  johnny depp
# 144                     dialogue
# 145                   conspiracy
# 146                    overrated
# 147                    brad pitt
# 148                   kidnapping
# 149                    road trip
# 150                    sexuality
# 151                      lesbian
# 152                     assassin
# 153                new york city
# 154                   small town
# 155  oscar nominee: best picture
# 156                      intense
# 157                ensemble cast
# 158                       clever
# 159                    tom hanks
# 160                        japan
# 161           strong female lead
# 162                    film noir
# 163                        pixar
# 164                       creepy
# 165              stand-up comedy
# 166                          spy
# 167                 bruce willis
# 168                       action
# 169                        death
#
#                                                   date  \
# 120                                              06-11
# 121                                              11-06
# 122                                              06-20
# 123                                              09-22
# 124                                              05-19
# 125                                              11-08
# 126                                              06-14
# 127                                              06-16
# 128                                              06-14
# 129                                              05-19
# 130                                              06-14
# 131                                              05-20
# 132                                              05-27
# 133                                              12-01
# 134  43    02-13
# 43    02-13
# Name: mth_day, dtype: ...
# 135                                              11-29
# 136                                              06-27
# 137                                              05-21
# 138                                              06-15
# 139  4    01-05
# 4    01-05
# Name: mth_day, dtype: ob...
# 140                                              06-12
# 141                                              05-19
# 142                                              06-20
# 143  215    08-03
# 215    08-03
# Name: mth_day, dtype...
# 144                                              06-14
# 145                                              07-12
# 146                                              05-19
# 147  152    06-01
# 152    06-01
# Name: mth_day, dtype...
# 148                                              05-27
# 149                                              06-17
# 150                                              05-19
# 151                                              08-24
# 152                                              05-20
# 153  160    06-09
# 160    06-09
# Name: mth_day, dtype...
# 154                                              06-10
# 155  143    05-23
# 143    05-23
# Name: mth_day, dtype...
# 156                                              05-19
# 157                                              05-19
# 158                                              05-23
# 159  126    05-06
# 126    05-06
# Name: mth_day, dtype...
# 160  133    05-13
# 133    05-13
# Name: mth_day, dtype...
# 161                                              06-13
# 162                                              06-20
# 163  126    05-06
# 126    05-06
# Name: mth_day, dtype...
# 164                                              06-15
# 165                                              04-24
# 166                                              05-30
# 167  141    05-21
# 141    05-21
# Name: mth_day, dtype...
# 168  176    25-Jun
# 176    25-Jun
# Name: mth_day, dty...
# 169                                              06-15
#
#                                             ravg_value
# 120                                            1.58982
# 121                                            1.28261
# 122                                            1.63175
# 123                                            1.41238
# 124                                            1.43701
# 125                                            1.35739
# 126                                            1.35051
# 127                                            1.85899
# 128                                            1.78286
# 129                                             1.6577
# 130                                            1.55148
# 131                                            2.07639
# 132                                            1.69055
# 133                                            1.52111
# 134      leonardo dicaprio_ravg  leonardo dicaprio_...
# 135                                            1.41107
# 136                                            1.39776
# 137                                            1.20183
# 138                                            1.27324
# 139     dvd-video_ravg  dvd-video_ravg
# 4           ...
# 140                                            1.43385
# 141                                             1.6279
# 142                                            1.73432
# 143       johnny depp_ravg  johnny depp_ravg
# 215   ...
# 144                                             1.3392
# 145                                            1.19516
# 146                                            1.73067
# 147       brad pitt_ravg  brad pitt_ravg
# 152       ...
# 148                                            1.60195
# 149                                            1.47211
# 150                                            1.85737
# 151                                            1.92198
# 152                                            1.48457
# 153       new york city_ravg  new york city_ravg
# 16...
# 154                                            1.78134
# 155       oscar nominee: best picture_ravg  oscar n...
# 156                                            1.50383
# 157                                            1.49304
# 158                                            1.65432
# 159       tom hanks_ravg  tom hanks_ravg
# 126       ...
# 160       japan_ravg  japan_ravg
# 133    1.491689   ...
# 161                                            1.27772
# 162                                            1.52857
# 163       pixar_ravg  pixar_ravg
# 126     2.50633   ...
# 164                                            1.62109
# 165                                            2.36519
# 166                                            1.34373
# 167       bruce willis_ravg  bruce willis_ravg
# 141 ...
# 168       action_ravg  action_ravg
# 176     1.741709...
# 169                                            1.85282

# %%
df2 = pd.DataFrame(columns=['tag','date','ravg_value'])
df1 = pd.read_csv("tags.csv")
n = 170
tag_array = df1['tag'].value_counts()[:n].index.tolist()
from pathlib import Path
import pandas as pd
root = Path('dataframe', 'daily_avg_over_yrs')
for tag in tag_array:
    tagn = tag+'.csv'
    df = pd.read_csv(root / tagn)
    df.columns = map(str.lower, df.columns)
    df[tag.lower()+'_ravg'] = df[tag.lower()+'_norm'].rolling(window=6,center=True).mean()
#     fig = df.plot(x='mth_day',y= tag+'_ravg',figsize = (15,8))
#     fig.figure.savefig('graphs/daily_avg_over_yrs/rolling_avg/'+ tag+'_ravg.pdf')
    df.to_csv('dataframe/daily_avg_over_yrs/'+ tag +'.csv')
