# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime
import numpy as np
import matplotlib.dates as mdates

# %%
df = pd.read_csv('avgTicSize.csv')
df2 = pd.read_csv('Users_Lost_PM.csv')
df2.set_index('FSM',inplace=True)

# %%
df2.head()
# Out:
#          CID   MID   TID
# FSM
# Jul-18  14.0  16.0  16.0
# Aug-18  20.0  22.0  22.0
# Sep-18  14.0  15.0  15.0
# Oct-18  13.0  18.0  18.0
# Nov-18  23.0  23.0  23.0

# %%
df.describe()
# Out:
#        Band 1 (0-15)  Band 2 (16-60)  Band 3 (61-120)  Band 4 (121-200)  \
# count      23.000000       23.000000        23.000000         23.000000
# mean     4931.155948     2081.875824      1720.267221       1391.124390
# std      1883.487185      765.756044       710.790265        564.555631
# min      1496.801688      790.788732       335.815185        690.772152
# 25%      4084.497017     1498.815750      1150.773694       1049.277868
# 50%      4658.320727     1990.188058      1964.333078       1289.473974
# 75%      5486.578042     2456.837679      2122.965206       1527.609398
# max      9908.892135     3792.698043      2712.024453       3439.106250
#
#        Band 5 (200+)
# count      23.000000
# mean      855.583098
# std        92.468978
# min       628.765846
# 25%       803.882239
# 50%       847.599744
# 75%       916.036629
# max      1027.066626

# %%
df.set_index('Frequency Band',inplace=True)

# %%
df.plot(figsize=(20,10))

# %%
df2.plot(figsize=(20,10))
